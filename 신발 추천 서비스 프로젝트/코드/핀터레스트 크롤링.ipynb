# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/chromedriver')
driver.get("https://www.pinterest.co.kr/")

# %%
element=driver.find_element_by_xpath("""//*[@id="searchBoxContainer"]/div/div/div[2]/input""")
element.send_keys('캐쥬얼 패션')

# %%
xpath="""//*[@id="searRgSelect"]"""
element_sel_gu=driver.find_element_by_xpath(xpath).click()

# %%
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver

driver = webdriver.Chrome('C:/chromedriver')
driver.get("https://www.pinterest.co.kr/")

# %%
#driver.execute_script("window.scrollTo(0,document.body.scrollHeight)") 
import datetime
    
def doScrollDown(whileSeconds):
        start = datetime.datetime.now()
        end = start + datetime.timedelta(seconds=whileSeconds)
        while True:
            
                
            driver.execute_script('window.scrollTo(0,window.scrollY + 800)')
            time.sleep(1)
            crowling()
            time.sleep(60)
            if datetime.datetime.now() > end:
                break
                
                


#driver.close()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time

# %%
driver = webdriver.Chrome('C:/chromedriver')
driver.get("https://www.pinterest.co.kr/")

# %%
insta = soup.select('div[data-test-id=pinrep-image]')

            #print(insta)
print(type(insta))

n = 1
for i in insta:
    #print('https://www.instagram.com'+ i.a['href'])
    imgUrl = i.select_one('div> div > div > div>div ').img['src']
    print(imgUrl)
    with urlopen(imgUrl) as f:
        with open('./img/casual/' +  str(n) + '.jpg', 'wb') as h:
            img = f.read()
            h.write(img)
    n += 1

# %%
def crowling():
    html = driver.page_source
    soup = BeautifulSoup(html)

    insta = soup.select('div[data-test-id=pinrep-image]')

            #print(insta)
    
    
    for i in insta:
        #print('https://www.instagram.com'+ i.a['href'])
        imgUrl = i.select_one('div> div > div > div>div ').img['src']
        print(imgUrl)
        img=imgUrl.split('/')
        print(img)
        with urlopen(imgUrl) as f:
            with open('./img/casual/' +  str(img[-1]), 'wb') as h:
                img = f.read()
                h.write(img)

# %%
doScrollDown(100000)
# Out:
# https://i.pinimg.com/236x/cc/52/61/cc5261c2fe2a774e55ab6b58bc4e7fab.jpg
# ['https:', '', 'i.pinimg.com', '236x', 'cc', '52', '61', 'cc5261c2fe2a774e55ab6b58bc4e7fab.jpg']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5f45c9eff74f> in <module>
# ----> 1 doScrollDown(100000)
#
# <ipython-input-2-17e02e3a7e67> in doScrollDown(whileSeconds)
#      10             driver.execute_script('window.scrollTo(0,window.scrollY + 800)')
#      11             time.sleep(1)
# ---> 12             crowling()
#      13             time.sleep(60)
#      14             if datetime.datetime.now() > end:
#
# <ipython-input-4-6e6ff9d9a440> in crowling()
#      14         img=imgUrl.split('/')
#      15         print(img)
# ---> 16         with urlopen(imgUrl) as f:
#      17             with open('./img/casual/' +  str(img[-1]), 'wb') as h:
#      18                 img = f.read()
# ...

# %%
imgUrl='https://i.pinimg.com/236x/5d/09/dd/5d09dd1060d0c4503c1ea1814e66ff5b.jpg'
img=imgUrl.split('/')
img[-1]
# Out:
# '5d09dd1060d0c4503c1ea1814e66ff5b.jpg'

# %%
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver

driver = webdriver.Chrome('C:/chromedriver')
driver.get("https://www.pinterest.co.kr/")

# %%
import time
import datetime

imgUrls=set()
    
def doScrollDown(whileSeconds):
        start = datetime.datetime.now()
        end = start + datetime.timedelta(seconds=whileSeconds)
        while True:
            
                
            driver.execute_script('window.scrollTo(0,window.scrollY + 800)')
            time.sleep(3)
            print('scroll')
            crowling()
            time.sleep(3)
            if datetime.datetime.now() > end:
                break
                
def crowling():
    html = driver.page_source
    soup = BeautifulSoup(html)

    insta = soup.select('div[data-test-id=pinrep-image]')

            #print(insta)
    
    
    for i in insta:
        #print('https://www.instagram.com'+ i.a['href'])
        imgUrl = i.select_one('div> div > div > div>div ').img['src']
        print(imgUrl)
        imgUrls.add(imgUrl)

# %%
crowling()
doScrollDown(500)
# Out:
# https://i.pinimg.com/236x/85/9d/15/859d156259edac5123ca8f55f12d5063.jpg
# https://i.pinimg.com/236x/bf/a5/c2/bfa5c21a30b2b37b816af6fe2e62e3e2.jpg
# https://i.pinimg.com/236x/6d/32/e0/6d32e0722326ce87ad8bb1ba5ad5bccf.jpg
# https://i.pinimg.com/236x/2d/d0/6b/2dd06b2f7ec21c1f2f36c3a793c99753.jpg
# https://i.pinimg.com/236x/50/55/69/505569456a1004fa4aaeb50154d398b2.jpg
# https://i.pinimg.com/236x/c2/bf/a7/c2bfa763a4192d5a3df82719ea3490fd.jpg
# https://i.pinimg.com/236x/2b/13/ee/2b13ee966337a2ed991d84c85c3f4d3f.jpg
# https://i.pinimg.com/236x/e6/77/dc/e677dcfc0b0733bf0668b99d5e5e7653.jpg
# https://i.pinimg.com/236x/35/e3/30/35e330f1d88be550c4a83a41beeb36d6.jpg
# https://i.pinimg.com/236x/21/2d/42/212d4269eabcb402283e9789ada2a95c.jpg
# https://i.pinimg.com/236x/16/28/a2/1628a2846838f0200e7f6afd26ced188.jpg
# https://i.pinimg.com/236x/60/db/30/60db30da1aa6fbbf834d7e9d586a534f.jpg
# https://i.pinimg.com/236x/89/22/e2/8922e2c8f787ba884b4641bb5707bca9.jpg
# scroll
# ...

# %%
  
imgUrls = list(imgUrls) 
imgUrls
# Out:
# ['https://i.pinimg.com/236x/38/e9/9a/38e99a1e0bca90cef627e024ce119371.jpg',
#  'https://i.pinimg.com/236x/75/be/ff/75beff33e2bb8db3f9a7ea5092a7c8a7.jpg',
#  'https://i.pinimg.com/236x/f9/7c/a8/f97ca8aedcf782bd72f76cd74aab3443.jpg',
#  'https://i.pinimg.com/236x/03/c2/c2/03c2c2a0b7201484c3c04dc70f45cde8.jpg',
#  'https://i.pinimg.com/236x/5a/70/b1/5a70b1e0f1a42c410775f1565aad373a.jpg',
#  'https://i.pinimg.com/236x/fd/b9/20/fdb92012eb39df2131e658a126254ec2.jpg',
#  'https://i.pinimg.com/236x/0c/81/4c/0c814cd1eda19b4f3ea8262ea9667c6e.jpg',
#  'https://i.pinimg.com/236x/77/cf/cf/77cfcfc34322984af754ceefa66eaca8.jpg',
#  'https://i.pinimg.com/236x/b0/98/4b/b0984bc6795ab85443e50e01404cd6d0.jpg',
#  'https://i.pinimg.com/236x/8b/63/9c/8b639c60119aacba2c0783af01d301a6.jpg',
#  'https://i.pinimg.com/236x/1c/24/f3/1c24f3bca783d0f00b7aaf04084cee4d.jpg',
#  'https://i.pinimg.com/236x/45/a9/bb/45a9bb1f5a52c7a8ad43b281b0f141f8.jpg',
# ...

# %%
from urllib.request import urlopen
for imgUrl in imgUrls:
        img=imgUrl.split('/')
        print(img)
        with urlopen(imgUrl) as f:
            with open('./img/newcasual/' +  str(img[-1]), 'wb') as h:
                img = f.read()
                h.write(img)
# Out:
# ['https:', '', 'i.pinimg.com', '236x', '38', 'e9', '9a', '38e99a1e0bca90cef627e024ce119371.jpg']
# ['https:', '', 'i.pinimg.com', '236x', '75', 'be', 'ff', '75beff33e2bb8db3f9a7ea5092a7c8a7.jpg']
# ['https:', '', 'i.pinimg.com', '236x', 'f9', '7c', 'a8', 'f97ca8aedcf782bd72f76cd74aab3443.jpg']
# ['https:', '', 'i.pinimg.com', '236x', '03', 'c2', 'c2', '03c2c2a0b7201484c3c04dc70f45cde8.jpg']
# ['https:', '', 'i.pinimg.com', '236x', '5a', '70', 'b1', '5a70b1e0f1a42c410775f1565aad373a.jpg']
# ['https:', '', 'i.pinimg.com', '236x', 'fd', 'b9', '20', 'fdb92012eb39df2131e658a126254ec2.jpg']
# ['https:', '', 'i.pinimg.com', '236x', '0c', '81', '4c', '0c814cd1eda19b4f3ea8262ea9667c6e.jpg']
# ['https:', '', 'i.pinimg.com', '236x', '77', 'cf', 'cf', '77cfcfc34322984af754ceefa66eaca8.jpg']
# ['https:', '', 'i.pinimg.com', '236x', 'b0', '98', '4b', 'b0984bc6795ab85443e50e01404cd6d0.jpg']
# ['https:', '', 'i.pinimg.com', '236x', '8b', '63', '9c', '8b639c60119aacba2c0783af01d301a6.jpg']
# ...

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import matplotlib.image as mping
import os
from PIL import Image

body_cascade=cv2.CascadeClassifier()
